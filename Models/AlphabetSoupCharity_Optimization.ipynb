# %% [markdown]
# ## Step 1: Data Preprocessing
# - Import libraries
# - Load the dataset
# - Drop unnecessary columns
# - Handle rare categorical values
# - Encode categorical variables
# - Split into features and target arrays
# - Split into training and testing datasets
# - Apply feature scaling

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import os

# %%
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
application_df.nunique()
# Out:
# EIN                       34299
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
application_df = application_df.drop(columns=["EIN", "NAME"])

application_count = application_df['APPLICATION_TYPE'].value_counts()

application_types_to_replace = list(application_count[application_count<100].index)
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app, "Other")

classification_counts = application_df["CLASSIFICATION"].value_counts()

classifications_to_replace = list(classification_counts[classification_counts<100].index)
for cls in classifications_to_replace:
    application_df["CLASSIFICATION"] = application_df["CLASSIFICATION"].replace(cls, "Other")

application_df = pd.get_dummies(application_df, dtype=float)

X = application_df.drop("IS_SUCCESSFUL", axis=1).values
y= application_df["IS_SUCCESSFUL"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Step 2: Model 1 - Initial Optimization
# - Build Model 1
# - Compile Model 1
# - Train Model 1

# %%
model_1 = tf.keras.models.Sequential()
model_1.add(tf.keras.layers.Dense(units=128, activation="relu", input_dim=X_train_scaled.shape[1]))
model_1.add(tf.keras.layers.Dense(units=64, activation="relu"))
model_1.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

model_1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

history_1 = model_1.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7064 - loss: 0.5835
# Epoch 2/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7273 - loss: 0.5547
# Epoch 3/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7286 - loss: 0.5505
# Epoch 4/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7264 - loss: 0.5516
# Epoch 5/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7316 - loss: 0.5463
# Epoch 6/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7285 - loss: 0.5465
# Epoch 7/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7366 - loss: 0.5432
# Epoch 8/100
# ...

# %% [markdown]
# ## Step 3: Model 2 - Additional Layer
# - Build Model 2
# - Compile Model 2
# - Train Model 2

# %%
model_2 = tf.keras.models.Sequential()
model_2.add(tf.keras.layers.Dense(units=128, activation="relu", input_dim=X_train_scaled.shape[1]))
model_2.add(tf.keras.layers.Dense(units=64, activation="relu"))
model_2.add(tf.keras.layers.Dense(units=32, activation="relu"))
model_2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

model_2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

history_2 = model_2.fit(X_train_scaled, y_train, epochs=150)
# Out:
# Epoch 1/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7068 - loss: 0.5876
# Epoch 2/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7246 - loss: 0.5561
# Epoch 3/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7264 - loss: 0.5561
# Epoch 4/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7282 - loss: 0.5514
# Epoch 5/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7334 - loss: 0.5435
# Epoch 6/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7313 - loss: 0.5477
# Epoch 7/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7306 - loss: 0.5464
# Epoch 8/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7312 - loss: 0.5492
# Epoch 9/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7356 - loss: 0.5429
# Epoch 10/150
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7331 - loss: 0.5432
# Epoch 11/150
# ...

# %% [markdown]
# ## Step 4: Model 3 - Different Activation Functions
# - Build Model 3
# - Compile Model 3
# - Train Model 3

# %%
from tensorflow.keras.layers import Dropout

model_3 = tf.keras.models.Sequential()

model_3.add(tf.keras.layers.Dense(units=64, activation="tanh", input_dim=X_train_scaled.shape[1]))
model_3.add(Dropout(0.3))

model_3.add(tf.keras.layers.Dense(units=32, activation="relu"))
model_3.add(Dropout(0.3))

model_3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

model_3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

history_3 = model_3.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6763 - loss: 0.6242
# Epoch 2/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7200 - loss: 0.5740
# Epoch 3/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7237 - loss: 0.5676
# Epoch 4/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7280 - loss: 0.5654
# Epoch 5/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7268 - loss: 0.5593
# Epoch 6/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7308 - loss: 0.5560
# Epoch 7/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7230 - loss: 0.5623
# Epoch 8/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7285 - loss: 0.5579
# Epoch 9/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7252 - loss: 0.5607
# Epoch 10/100
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7281 - loss: 0.5601
# Epoch 11/100
# ...

# %% [markdown]
# ## Step 5: Results Comparison
# - Evaluate all three models
# - Compare accuracies

# %%
loss_1, acc_1 = model_1.evaluate(X_test_scaled, y_test)
loss_2, acc_2 = model_2.evaluate(X_test_scaled, y_test)
loss_3, acc_3 = model_3.evaluate(X_test_scaled, y_test)

print(f"Model 1 Accuracy: {acc_1}")
print(f"Model 2 Accuracy: {acc_2}")
print(f"Model 3 Accuracy: {acc_3}")
# Out:
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7264 - loss: 0.5702
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7271 - loss: 0.5886
# 268/268 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7334 - loss: 0.5534
# Model 1 Accuracy: 0.7286297082901001
# Model 2 Accuracy: 0.72967928647995
# Model 3 Accuracy: 0.734810471534729

# %% [markdown]
# ## Step 6: Save Best Model
# - Save the model with the highest accuracy as "AlphabetSoupCharity_Optimization.h5"

# %%
model_2.save("/content/AlphabetSoupCharity_Optimization.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import files
files.download("/content/AlphabetSoupCharity_Optimization.h5")
